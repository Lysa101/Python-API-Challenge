# %%
import matplotlib.pyplot as plt
import json
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from config import wkey

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# %%
url="https://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
#wkey = "&wkey=" + wkey

# %%
#query_url = f"{url}appid={wkey}&units={units}&q="

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

#List for responses
temps = []
humidity = []
cloudiness = []
wind_speed = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 597

# %%
query_url = "https://api.openweathermap.org/data/2.5/weather?units=imperial&appid=0cc4f4878d428462ef678cb5c8069b3c&q="
print(query_url)

# API call
for city in cities:
    try:
        response = requests.get(query_url + city).json()
    
    
#info fields
        weather = response['coord']['lat']
        weather2 = response['coord']['lng']
        temp = response['main']['temp_max']
        cloudiness = response['clouds']['all']
        wind_speed = response['wind']['speed']
        humidity = response['main']['humidity']
    except:
        print("negative")
# Out:
# https://api.openweathermap.org/data/2.5/weather?units=imperial&appid=0cc4f4878d428462ef678cb5c8069b3c&q=
# negative
# negative
# negative
# negative
# negative
# negative
# negative
# negative
# negative
# negative
# negative
# negative
# negative
# negative
# negative
# negative
# negative
# negative
# negative
# negative
# negative
# negative
# negative
# negative
# negative
# negative
# negative
# negative
# negative
# negative
# negative
# negative
# negative
# negative
# negative
# negative
# negative
# negative
# negative
# negative
# negative
# negative
# negative
# negative
# negative
# negative
# negative
# negative
# negative
# negative
# negative
# negative
# negative
# negative
# negative
# negative
# negative
# negative
# negative
# negative
# negative
# negative
# negative
# negative
# negative
# negative
# negative
# negative
# negative
# negative
# negative
# negative
# negative
# negative
# negative
# negative
# negative
# negative
# negative
# negative
# negative
# ...

# %%
# create a data frame 
weather = {
    "city": cities,
    "lat": lat,
    "lon":lon,
    "temp": temps
    "cloudiness":cloudiness
    "wind speed":wind_speed
}
weather_df = pd.DataFrame(weather)
weather.head()
# Out:
#   File "<ipython-input-10-9572dc3eb056>", line 7
#     "cloudiness":cloudiness
#     ^
# SyntaxError: invalid syntax

# %%
# Build a scatter plot for each data type
#Temperature (F) vs. Latitude,
#Humidity (%) vs. Latitude,
#Cloudiness (%) vs. Latitude,
#Wind Speed (mph) vs. Latitude
plt.scatter(weather_df["lat"], weather_df["temp"], marker="o")

# Incorporate the other graph properties
plt.title("Temperature in World Cities")
plt.ylabel("Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("TemperatureInWorldCities.png")

# Show plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-aeccd122b596> in <module>
#       4 #Cloudiness (%) vs. Latitude,
#       5 #Wind Speed (mph) vs. Latitude
# ----> 6 plt.scatter(weather_df["lat"], weather_df["temp"], marker="o")
#       7
#       8 # Incorporate the other graph properties
#
# NameError: name 'weather_df' is not defined
